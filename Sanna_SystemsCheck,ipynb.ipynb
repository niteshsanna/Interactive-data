# %% [markdown]
# # Assignment 1

# %% [markdown]
# ##### Nitesh Yadav Sanna

# %% [markdown]
# **Interactive Data**<br>
# **Instructor**: _David E. Silva, Ph.D_

# %% [markdown]
# Things I will Learn from this class:
# * **Custom Visualization Techniques**: Learn to develop graphic solutions that are unique, much more than simple graphic presentations, but that are adapted to specific values, formats and audiences.
#
# * **Data-Driven Decision Making**: Discover how and when to apply the visuals to present various types of data in different fields – business, education, healthcare, and research.
#
# * **Ethics in Data Visualization**: Appreciate the ethical implications of data visualization, embrace high standards of accuracy in presenting information as well as abstaining from creating deceptive data visualizations and use proper representations in presenting data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# variable assignment
num=244
print(num)
# Out:
# 244

# %%
#for loop
listing_names=["Nitesh","Sai","Vineeth"]
for i in listing_names:
    print(i)
# Out:
# Nitesh
# Sai
# Vineeth

# %%
# a function with a print statement

def remainder(a,b):
    r=a%b
    print(r)

# %%
remainder(32,3)
# Out:
# 2

# %%
# a function with a return statement

def remainder_withreturn(a,b):
    r=a%b
    return r

# %%
remainder_withreturn(32,3)
# Out:
# 2
